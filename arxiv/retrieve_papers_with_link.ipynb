# %% [markdown]
# ## Retrieving Arxiv Papers

# %%
# !pip install feedparser
# Out:
# Requirement already satisfied: feedparser in /opt/anaconda3/lib/python3.11/site-packages (6.0.11)
# Requirement already satisfied: sgmllib3k in /opt/anaconda3/lib/python3.11/site-packages (from feedparser) (1.0.0)

# %% [markdown]
# ## Filtering Search to only Papers under the category: CS

# %%
## 2023-01-01 to 2024-12-31

import time
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# Base OAI-PMH URL for arXiv
base_url = 'http://export.arxiv.org/oai2?verb=ListRecords'

# Search parameters for OAI-PMH (for Computer Science category and metadata format 'oai_dc')
metadata_format = 'oai_dc'
category = 'cs'  # Computer Science category
from_date = '2023-01-01'  # Start date (YYYY-MM-DD)
until_date = '2024-12-31'  # End date (YYYY-MM-DD)

# List to store the data
data = []

# Initial request URL (without a resumptionToken)
url = f'{base_url}&metadataPrefix={metadata_format}&from={from_date}&until={until_date}&set={category}'

while True:
    # Fetch the data
    response = requests.get(url)
    response_text = response.text
    
    # Parse the response using ElementTree
    root = ET.fromstring(response_text)

    # Find all the 'record' elements in the XML
    records = root.findall('.//{http://www.openarchives.org/OAI/2.0/}record')
    
    # Iterate over each record and extract relevant fields
    for record in records:
        metadata = record.find('.//{http://www.openarchives.org/OAI/2.0/oai_dc/}dc')
        
        if metadata is not None:
            title = metadata.find('.//{http://purl.org/dc/elements/1.1/}title').text if metadata.find('.//{http://purl.org/dc/elements/1.1/}title') is not None else 'N/A'
            summary = metadata.find('.//{http://purl.org/dc/elements/1.1/}description').text if metadata.find('.//{http://purl.org/dc/elements/1.1/}description') is not None else 'N/A'
            updated = record.find('.//{http://www.openarchives.org/OAI/2.0/}datestamp').text
            category = metadata.find('.//{http://purl.org/dc/elements/1.1/}subject').text if metadata.find('.//{http://purl.org/dc/elements/1.1/}subject') is not None else 'N/A'
            
            # Append the data to the list
            data.append({
                'Title': title,
                'Summary': summary,
                'Updated': updated,
                'Category': category
            })

    # Find resumptionToken for pagination (if available)
    resumption_token = root.find('.//{http://www.openarchives.org/OAI/2.0/}resumptionToken')

    # If there is no resumptionToken, we have retrieved all the data
    if resumption_token is None or resumption_token.text is None:
        break

    # Update the URL with the resumptionToken for the next batch of records
    token = resumption_token.text
    url = f'{base_url}&resumptionToken={token}'

    # Sleep for 3 seconds to avoid overwhelming the server
    print("Sleeping for 3 seconds before the next request...")
    time.sleep(3)

# Convert the list of entries into a pandas DataFrame
df = pd.DataFrame(data)

# Convert the 'Updated' column to datetime format
df['Updated'] = pd.to_datetime(df['Updated'])

# Display the DataFrame
display(df)
# Out:
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
# Sleeping for 3 seconds before the next request...
#                                                     Title  \
# 0       Third Order Newton's Method for Zernike Polyno...
# 1       A recursive linear time modular decomposition ...
# 2       Tur\'an Graphs, Stability Number, and Fibonacc...
# 3                             Projective Expected Utility
# 4       A Universal In-Place Reconfiguration Algorithm...
# ...                                                   ...
# 217847  On Approximately Symmetric Informationally Com...
# 217848  Limitations of Quantum Coset States for Graph ...
# 217849        Computing Local Invariants of Qubit Systems
# 217850  Fast Quantum Fourier Transforms for a Class of...
# 217851  Polynomial-Time Solution to the Hidden Subgrou...
#
#                                                   Summary    Updated  \
# 0         The Zernike radial polynomials are a system ... 2024-04-23
# 1         A module of a graph G is a set of vertices t... 2024-07-15
# 2         The Fibonacci index of a graph is the number... 2024-03-11
# 3         Motivated by several classic decision-theore... 2024-01-18
# 4         In the modular robot reconfiguration problem... 2024-03-15
# ...                                                   ...        ...
# 217847    We address the problem of constructing posit... 2023-11-27
# 217848    It has been known for some time that graph i... 2023-11-27
# 217849    We investigate means to describe the non-loc... 2023-11-27
# 217850    An algorithm is presented allowing the const... 2023-11-27
# 217851    We present a family of non-abelian groups fo... 2023-11-27
#
#                                          Category
# 0                Mathematics - Numerical Analysis
# 1         Computer Science - Discrete Mathematics
# 2         Computer Science - Discrete Mathematics
# 3                                 Quantum Physics
# 4       Computer Science - Computational Geometry
# ...                                           ...
# 217847                            Quantum Physics
# 217848                            Quantum Physics
# 217849                            Quantum Physics
# 217850                            Quantum Physics
# 217851                            Quantum Physics
#
# [217852 rows x 4 columns]

# %%
#2022

import requests
import xml.etree.ElementTree as ET
import pandas as pd

# Base OAI-PMH URL for arXiv
base_url = 'http://export.arxiv.org/oai2?verb=ListRecords'

# Search parameters for OAI-PMH (for Computer Science category and metadata format 'oai_dc')
metadata_format = 'oai_dc'
category = 'cs'  # Computer Science category
from_date = '2023-01-01'  # Start date (YYYY-MM-DD)
until_date = '2023-12-31'  # End date (YYYY-MM-DD)

# List to store the data
data = []

# Initial request URL (without a resumptionToken)
url = f'{base_url}&metadataPrefix={metadata_format}&from={from_date}&until={until_date}&set={category}'

# Fetch the data
response = requests.get(url)
response_text = response.text

# Parse the response using ElementTree
root = ET.fromstring(response_text)

# Find all the 'record' elements in the XML
records = root.findall('.//{http://www.openarchives.org/OAI/2.0/}record')

# Iterate over each record and extract relevant fields (limit to 10)
for record in records[:100]:
    metadata = record.find('.//{http://www.openarchives.org/OAI/2.0/oai_dc/}dc')
    
    if metadata is not None:
        title = metadata.find('.//{http://purl.org/dc/elements/1.1/}title').text if metadata.find('.//{http://purl.org/dc/elements/1.1/}title') is not None else 'N/A'
        summary = metadata.find('.//{http://purl.org/dc/elements/1.1/}description').text if metadata.find('.//{http://purl.org/dc/elements/1.1/}description') is not None else 'N/A'
        updated = record.find('.//{http://www.openarchives.org/OAI/2.0/}datestamp').text
        category = metadata.find('.//{http://purl.org/dc/elements/1.1/}subject').text if metadata.find('.//{http://purl.org/dc/elements/1.1/}subject') is not None else 'N/A'
        
        # Extract the identifier (article link)
        identifier = metadata.find('.//{http://purl.org/dc/elements/1.1/}identifier').text if metadata.find('.//{http://purl.org/dc/elements/1.1/}identifier') is not None else 'N/A'
        
        # Convert arXiv identifier to URL
        if identifier.startswith('http://arxiv.org/abs/'):
            link = identifier
        elif identifier.startswith('arXiv:'):
            link = f'http://arxiv.org/abs/{identifier[6:]}'
        else:
            link = f'http://arxiv.org/abs/{identifier}'
        
        # Append the data to the list
        data.append({
            'Title': title,
            'Summary': summary,
            'Updated': updated,
            'Category': category,
            'Link': link
        })

# Convert the list of entries into a pandas DataFrame
df = pd.DataFrame(data)

# Convert the 'Updated' column to datetime format
df['Updated'] = pd.to_datetime(df['Updated'])

# Display the DataFrame
display(df)
# Out:
#                                                 Title  \
# 0   On the `Semantics' of Differential Privacy: A ...
# 1      On the Dual Formulation of Boosting Algorithms
# 2   Domain Adaptation: Learning Bounds and Algorithms
# 3   Q-system Cluster Algebras, Paths and Total Pos...
# 4   Optimization of Synthesis Oversampled Complex ...
# ..                                                ...
# 95  Graphs of Edge-Intersecting Non-Splitting Path...
# 96  Multiuser Diversity for Secrecy Communications...
# 97               When does a physical system compute?
# 98  SVD Factorization for Tall-and-Fat Matrices on...
# 99  Can social microblogging be used to forecast i...
#
#                                               Summary    Updated  \
# 0     Differential privacy is a definition of "pri... 2023-01-24
# 1     We study boosting algorithms from a new pers... 2023-05-30
# 2     This paper addresses the general problem of ... 2023-12-04
# 3     We review the solution of the $A_r$ Q-system... 2023-07-12
# 4     An important issue with oversampled FIR anal... 2023-01-19
# ..                                                ...        ...
# 95    Given a tree and a set P of non-trivial simp... 2023-06-22
# 96    In this paper, we propose opportunistic jamm... 2023-07-19
# 97    Computing is a high-level process of a physi... 2023-04-21
# 98    We demonstrate an implementation for an appr... 2023-04-04
# 99    The Efficient Market Hypothesis (EMH) is wid... 2023-03-24
#
#                                              Category  \
# 0        Computer Science - Cryptography and Security
# 1                 Computer Science - Machine Learning
# 2                 Computer Science - Machine Learning
# 3                       Economics - General Economics
# 4               Computer Science - Information Theory
# ..                                                ...
# 95            Computer Science - Discrete Mathematics
# 96              Computer Science - Information Theory
# 97           Computer Science - Emerging Technologies
# 98  Computer Science - Distributed, Parallel, and ...
# 99  Computer Science - Social and Information Netw...
#
#                               Link
# 0   http://arxiv.org/abs/0803.3946
# 1   http://arxiv.org/abs/0901.3590
# 2   http://arxiv.org/abs/0902.3430
# 3   http://arxiv.org/abs/0906.3421
# 4   http://arxiv.org/abs/0907.3654
# ..                             ...
# 95  http://arxiv.org/abs/1309.6471
# 96  http://arxiv.org/abs/1309.7451
# 97  http://arxiv.org/abs/1309.7979
# 98  http://arxiv.org/abs/1310.4664
# 99  http://arxiv.org/abs/1310.5306
#
# [100 rows x 5 columns]

# %%
# Saving the DataFrame to a CSV file
df.to_csv('100_arxiv_cs_papers_2023_2023.csv', index=False)

# %%
# Saving the DataFrame to a CSV file
df.to_csv('arxiv_cs_papers_2022.csv', index=False)

# %%
display(df)
# Out:
#                                                    Title  \
# 0      Solution of moving-boundary problems by the sp...
# 1      A Polynomial Time Algorithm for Graph Isomorphism
# 2      On the Frame Error Rate of Transmission Scheme...
# 3      Diversity-Integration Trade-offs in MIMO Detec...
# 4      Perfect tag identification protocol in RFID ne...
# ...                                                  ...
# 82440  Bounded-Error Quantum State Identification and...
# 82441  Strengths and Weaknesses of Quantum Fingerprin...
# 82442                 On the Role of Shared Entanglement
# 82443  Exponential Separation of Quantum and Classica...
# 82444  Classical Interaction Cannot Replace a Quantum...
#
#                                                  Summary    Updated  \
# 0        This paper describes a novel numerical model... 2022-09-29
# 1        We claimed that there is a polynomial algori... 2022-10-18
# 2        It is known that the frame error rate of tur... 2022-03-08
# 3        In this work, a MIMO detection problem is co... 2022-03-09
# 4        Radio Frequency IDentification (RFID) system... 2022-07-04
# ...                                                  ...        ...
# 82440    We consider the problem of bounded-error qua... 2022-03-29
# 82441    We study the power of quantum fingerprints i... 2022-03-29
# 82442    Despite the apparent similarity between shar... 2022-03-29
# 82443    We give an exponential separation between on... 2022-03-29
# 82444    We demonstrate a two-player communication pr... 2022-03-29
#
#                                                 Category
# 0      Computer Science - Computational Engineering, ...
# 1            Computer Science - Computational Complexity
# 2                  Computer Science - Information Theory
# 3              Computer Science - Other Computer Science
# 4      Computer Science - Networking and Internet Arc...
# ...                                                  ...
# 82440                                    Quantum Physics
# 82441                                    Quantum Physics
# 82442                                    Quantum Physics
# 82443                                    Quantum Physics
# 82444                                    Quantum Physics
#
# [82445 rows x 4 columns]

# %%
# Get the counts of all unique entries in the 'Category' column
category_counts = df['Category'].value_counts()

# Print the counts of all unique entries in the 'Category' column
print("\nCounts of all unique entries in column 'Category':")
print(category_counts)
# Out:
# Counts of all unique entries in column 'Category':
# Category
# Computer Science - Computer Vision and Pattern Recognition    14353
# Computer Science - Machine Learning                           13769
# Computer Science - Computation and Language                    7032
# Computer Science - Robotics                                    3719
# Mathematics - Numerical Analysis                               2928
#                                                               ...
# Quantitative Biology - Cell Behavior                              1
# Condensed Matter - Other Condensed Matter                         1
# Nonlinear Sciences - Pattern Formation and Solitons               1
# Physics - Atomic and Molecular Clusters                           1
# Mathematics - Operator Algebras                                   1
# Name: count, Length: 146, dtype: int64

# %%
# Filter entries that start with "Computer Science"
filtered_df = df[df['Category'].str.startswith('Computer Science')]

# Display the filtered DataFrame
print("\nFiltered DataFrame where 'Category' starts with 'Computer Science':")
display(filtered_df)
# Out:
# Filtered DataFrame where 'Category' starts with 'Computer Science':
#                                                    Title  \
# 0      Solution of moving-boundary problems by the sp...
# 1      A Polynomial Time Algorithm for Graph Isomorphism
# 2      On the Frame Error Rate of Transmission Scheme...
# 3      Diversity-Integration Trade-offs in MIMO Detec...
# 4      Perfect tag identification protocol in RFID ne...
# ...                                                  ...
# 82430                   Notes for Miscellaneous Lectures
# 82431  Throughput Optimal Distributed Control of Stoc...
# 82432      On the intersection of additive perfect codes
# 82433  A Union Bound Approximation for Rapid Performa...
# 82434  A Computational Memory and Processing Model fo...
#
#                                                  Summary    Updated  \
# 0        This paper describes a novel numerical model... 2022-09-29
# 1        We claimed that there is a polynomial algori... 2022-10-18
# 2        It is known that the frame error rate of tur... 2022-03-08
# 3        In this work, a MIMO detection problem is co... 2022-03-09
# 4        Radio Frequency IDentification (RFID) system... 2022-07-04
# ...                                                  ...        ...
# 82430    Here I share a few notes I used in various c... 2022-07-20
# 82431    This paper has been withdrawn by the author ... 2022-04-26
# 82432    The intersection problem for additive (exten... 2022-04-26
# 82433    In this paper, we present a simple technique... 2022-03-08
# 82434    This paper links prosody to the information ... 2022-04-04
#
#                                                 Category
# 0      Computer Science - Computational Engineering, ...
# 1            Computer Science - Computational Complexity
# 2                  Computer Science - Information Theory
# 3              Computer Science - Other Computer Science
# 4      Computer Science - Networking and Internet Arc...
# ...                                                  ...
# 82430            Computer Science - Discrete Mathematics
# 82431  Computer Science - Networking and Internet Arc...
# 82432              Computer Science - Information Theory
# 82433              Computer Science - Information Theory
# 82434        Computer Science - Computation and Language
#
# [64674 rows x 4 columns]

# %%
# Convert the filtered DataFrame to a CSV file
filtered_df.to_csv('arxiv_cs_papers_2022_clean.csv', index=False)

# %%
import pandas as pd

# Define the paths for the CSV files
path_2023_2024 = '/Users/bryansoh/Documents/NUS/PLP/Group Project/plp_practice_proj-1/arxiv/datasets/arxiv_cs_papers_2023_2024_clean.csv'
path_2022 = '/Users/bryansoh/Documents/NUS/PLP/Group Project/plp_practice_proj-1/arxiv/arxiv_cs_papers_2022_clean.csv'

# Load the first CSV file
df1 = pd.read_csv(path_2023_2024)

# Load the second CSV file
df2 = pd.read_csv(path_2022)

# Combine the two DataFrames
combined_df = pd.concat([df1, df2])

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('arxiv_cs_papers_2022_2024_clean.csv', index=False)

# %%
display(combined_df)
# Out:
#                                                    Title  \
# 0      A recursive linear time modular decomposition ...
# 1      Tur\'an Graphs, Stability Number, and Fibonacc...
# 2      A Universal In-Place Reconfiguration Algorithm...
# 3      New probabilistic interest measures for associ...
# 4      On the `Semantics' of Differential Privacy: A ...
# ...                                                  ...
# 64669                   Notes for Miscellaneous Lectures
# 64670  Throughput Optimal Distributed Control of Stoc...
# 64671      On the intersection of additive perfect codes
# 64672  A Union Bound Approximation for Rapid Performa...
# 64673  A Computational Memory and Processing Model fo...
#
#                                                  Summary     Updated  \
# 0        A module of a graph G is a set of vertices t...  2024-07-15
# 1        The Fibonacci index of a graph is the number...  2024-03-11
# 2        In the modular robot reconfiguration problem...  2024-03-15
# 3        Mining association rules is an important tec...  2024-01-01
# 4        Differential privacy is a definition of "pri...  2023-01-24
# ...                                                  ...         ...
# 64669    Here I share a few notes I used in various c...  2022-07-20
# 64670    This paper has been withdrawn by the author ...  2022-04-26
# 64671    The intersection problem for additive (exten...  2022-04-26
# 64672    In this paper, we present a simple technique...  2022-03-08
# 64673    This paper links prosody to the information ...  2022-04-04
#
#                                                 Category
# 0                Computer Science - Discrete Mathematics
# 1                Computer Science - Discrete Mathematics
# 2              Computer Science - Computational Geometry
# 3                           Computer Science - Databases
# 4           Computer Science - Cryptography and Security
# ...                                                  ...
# 64669            Computer Science - Discrete Mathematics
# 64670  Computer Science - Networking and Internet Arc...
# 64671              Computer Science - Information Theory
# 64672              Computer Science - Information Theory
# 64673        Computer Science - Computation and Language
#
# [240172 rows x 4 columns]
